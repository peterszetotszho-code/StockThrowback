# %% [markdown]
# # Exploration
#
# Load market data and inspect the computed indicators for a single ticker.

# %%
from src.data_loader import fetch_stock_data
from src.indicators import add_all_indicators

df = fetch_stock_data("0700.HK", "2022-01-01", "2024-12-31")
df = add_all_indicators(df)
df.tail()

# %%
cols = ["Close", "MA5", "MA20", "MA60", "RSI"]
df[cols].plot(subplots=True, figsize=(10, 8))

# %%
df["Trend_State"].value_counts()
